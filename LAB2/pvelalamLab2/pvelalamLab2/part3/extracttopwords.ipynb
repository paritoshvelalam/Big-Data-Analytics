# %%
import pandas as pd
data1 = pd.read_csv(r"D:\hadoop\twitter\tennis\wordcooccurancessmalltop20",sep="\t", header=None)
data1.columns= ['word','count']
df_sort = data1.sort_values('count',ascending=False)
top100 = df_sort[0:100]
top100
# Out:
#                      word  count
# 172243      tennis|tennis  58387
# 39371          boy|tennis   7759
# 115898        play|tennis   7735
# 166932        tennis|play   7277
# 172106        tennis|team   7078
# 175315         tennis|win   6755
# 81262         girl|tennis   6423
# 151647         tennis|boy   6239
# 147124        team|tennis   6189
# 228992         win|tennis   5874
# 157868        tennis|girl   5793
# 173155       tennis|today   5675
# 163300       tennis|match   5467
# 92488        match|tennis   4946
# 166940      tennis|player   4737
# 194067       today|tennis   4703
# 150445        tennis|ball   4641
# 153913       tennis|court   4549
# 149558         tennis|amp   4045
# 8209           amp|tennis   4033
# 103235      player|tennis   3905
# 173321  tennis|tournament   3817
# 17663         ball|tennis   3794
# 58345          day|tennis   3686
# 48926        court|tennis   3555
# 170948       tennis|sport   3533
# 154535         tennis|day   3507
# ...

# %%
top100.to_csv(r"D:\hadoop\twitter\tennis\twittertenniswordcooccurancessmalltop100.csv",index=False)
