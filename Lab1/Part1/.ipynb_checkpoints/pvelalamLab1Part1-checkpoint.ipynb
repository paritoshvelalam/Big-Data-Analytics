# %% [markdown]
# # Paritosh Kumar Velalam
# # Gaurav Avula

# %% [markdown]
# # Problem 1
#
# # First run

# %%
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)  # random numbers, Poisson distribution, mean at 34, 12 numbers
par(bg="cornsilk")

plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %% [markdown]
# # Second Run

# %%
sales1<-c(12,14,16,29,30,45,19,20,16, 19, 34, 20)
sales2<-rpois(12,34)  # random numbers, Poisson distribution, mean at 34, 12 numbers
par(bg="cornsilk")

plot(sales1, col="blue", type="o", ylim=c(0,100), xlab="Month", ylab="Sales" )
title(main="Sales by Month")

lines(sales2, type="o", pch=22, lty=2, col="red")
grid(nx=NA, ny=NULL)
legend("topright", inset=.05, c("Sales1","Sales2"), fill=c("blue","red"), horiz=TRUE)
# Out:
# Plot with title “Sales by Month”

# %% [markdown]
# rpois() function produces different data everytime it is run

# %% [markdown]
# # Problem 2

# %%
sales<-read.delim(file = "salesdata.txt", header = TRUE)
sales 
barplot(as.matrix(sales), main="Sales Data", ylab= "Total", ylim= c(0,100), beside=T, col=rainbow(5))
# Out:
#    Sales1 Sales2
# 1  34     45
# 2  23     23
# 3  12     56
# 4  29     34
# 5  34     45
# 6  34     56
# 7  12     89
# 8  80     36
# 9  80     44
# 10 56     66
# 11 55     60
# 12 45     23
# Plot with title “Sales Data”

# %% [markdown]
# Read.dlim function is used to import data.
# Boxi of Sales1 can be compared to Boxj of Sales2
# Higher number of Sales can be identified by peak
# Included ylim=c(0,100) to plot correctly

# %% [markdown]
# # Problem 3

# %%
fn<-boxplot(sales,col=c("orange","green"))$stats
text(1.45, fn[3,2], paste("Median =", fn[3,2]), adj=0, cex=.7)
text(0.45, fn[3,1],paste("Median =", fn[3,1]), adj=0, cex=.7)
grid(nx=NA, ny=NULL)
# Out:
# plot without title

# %% [markdown]
# boxplot.stats function gathers the statistics necessary for producing box plots
#
# A vector of length 5, containing the extreme of the lower whisker(minimum), the lower ‘hinge’(1st Quartile), the median, the upper ‘hinge’(3rd Quartile) and the extreme of the upper whisker(maximum) is returned as stats.

# %% [markdown]
# # Problem 4

# %%
fb1<-read.csv(file = "FB.csv", header = TRUE)
aapl1<-read.csv(file = "AAPL.csv", header = TRUE)
par(bg="cornsilk")
plot(aapl1$Adj.Close, col="blue", type="o", ylim=c(0,400), xlab="Days", ylab="Price" )
lines(fb1$Adj.Close, type="o", pch=22, lty=2, col="red")
legend("topright", inset=.05, c("Apple","Facebook"), fill=c("blue","red"), horiz=TRUE)
hist(aapl1$Adj.Close, col=rainbow(8), ylim= c(0,20))
# Out:
# plot without title
# Plot with title “Histogram of aapl1$Adj.Close”

# %% [markdown]
# Facebook's Adj Close is higher than Apple's Adj Close
# Apple's Adj Close Price is 175 seventeen times

# %% [markdown]
# # Problem 5

# %%
data()

# %% [markdown]
# Displays datasets in the library

# %%
attach(as.data.frame(AirPassengers))

# %% [markdown]
# The database is attached to the R search path

# %%
head(AirPassengers)
# Out:
# [1] 112 118 132 129 121 135

# %% [markdown]
# head(dataframe) or head(dataframe,n=number) function returns the number of first rows n of a matrix or data frame.
# If no n is specified six rows are returned

# %%
summary(AirPassengers)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   104.0   180.0   265.5   280.3   360.5   622.0

# %% [markdown]
# summary(object) function provides a range of descriptive statistics at once

# %%
detach(as.data.frame(AirPassengers))

# %% [markdown]
# detach(object) function  removes the object from the search() path of available R objects

# %%
library (help=datasets)
library(datasets)
head(uspop)
plot(uspop)
# Out:
# [1]  3.93  5.31  7.24  9.64 12.90 17.10
# plot without title

# %% [markdown]
# library(package) loads the namespace of package with name package and attach it on the search list

# %% [markdown]
# # Problem 6

# %%
library("ggmap")
library("maptools")
library(maps)
register_google(key = 'AIzaSyAet5b7jMbb8lZWgleaiuoVdpX1eZSBXCg') 
visited <- c("SFO", "Chennai", "London", "Melbourne", "Lima, Peru", "Johannesbury, SA")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("world", fill=TRUE, col="white", bg="lightblue", ylim=c(-60, 90), mar=c(0,0,0,0))
points(visit.x,visit.y, col="red", pch=36)
# Out:
# Loading required package: ggplot2
# Google's Terms of Service: https://cloud.google.com/maps-platform/terms/.
# Please cite ggmap if you use it! See citation("ggmap") for details.
# Loading required package: sp
# Checking rgeos availability: FALSE
#  	Note: when rgeos is not available, polygon geometry 	computations in maptools depend on gpclib,
#  	which has a restricted licence. It is disabled by default;
#  	to enable gpclib, type gpclibPermit()
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Chennai&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=London&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Melbourne&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Lima,+Peru&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Johannesbury,+SA&key=xxx
# plot without title

# %%
library("ggmap")
library("maptools")
library(maps)
visited <- c("SFO", "New York", "Buffalo", "Dallas, TX")
ll.visited <- geocode(visited)
visit.x <- ll.visited$lon
visit.y <- ll.visited$lat
map("state", fill=TRUE, col=rainbow(50), bg="lightblue", mar=c(0,0,0,0))
points(visit.x,visit.y, col="yellow", pch=36)
# Out:
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=SFO&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=New+York&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Buffalo&key=xxx
# Source : https://maps.googleapis.com/maps/api/geocode/json?address=Dallas,+TX&key=xxx
# plot without title

# %% [markdown]
# # Problem 7

# %%
attach(mtcars)
head(mtcars)
# Out:
# The following object is masked from package:ggplot2:
#
#     mpg
#                   mpg  cyl disp hp  drat wt    qsec  vs am gear carb
# Mazda RX4         21.0 6   160  110 3.90 2.620 16.46 0  1  4    4
# Mazda RX4 Wag     21.0 6   160  110 3.90 2.875 17.02 0  1  4    4
# Datsun 710        22.8 4   108   93 3.85 2.320 18.61 1  1  4    1
# Hornet 4 Drive    21.4 6   258  110 3.08 3.215 19.44 1  0  3    1
# Hornet Sportabout 18.7 8   360  175 3.15 3.440 17.02 0  0  3    2
# Valiant           18.1 6   225  105 2.76 3.460 20.22 1  0  3    1

# %%
plot(mtcars[c(1,3,4,5,6)], main="MTCARS Data")
# Out:
# plot without title

# %%
plot(mtcars[c(1,3,4,6)], main="MTCARS Data")
# Out:
# plot without title

# %%
plot(mtcars[c(1,3,4,6)], col=rainbow(5),main="MTCARS Data")
# Out:
# plot without title

# %%
attach(iris) # iris dataset

# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
plot(iris[c(1,2,3)], main="Edgar Anderson's Iris Data")
# Out:
# plot without title

# %%
plot(iris[c(1,2,3,4)], col=rainbow(5), main="Edgar Anderson's Iris Data")
# Out:
# plot without title

# %% [markdown]
# # Problem 8

# %%
library(ggplot2)
ggplot(mtcars, aes(x=mpg, y=disp)) + geom_point()
# Out:
# plot without title

# %% [markdown]
# geom_point() is used to create scatter plots
